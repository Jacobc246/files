# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacobc246/files/blob/main/notebooks/starter_publishing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
restart = True
epoch_to_pickup = 0

# %%
# Import libraries

from tensorflow.keras.layers import StringLookup
import numpy as np
import os
import time
import random
import contextlib
import io
import re
import string
import gc  # Import the garbage collector module

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.layers import TextVectorization

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
path = ''

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# path = '/content/drive/My Drive/M6_Fall2023e/'

# %% [markdown]
# ## Functions for downloading text

# %%
def preprocess_text(text):

    text = text.replace("Project Gutenberg", "")
    text = text.replace("Gutenberg", "")

    # Remove carriage returns
    text = text.replace("\r", "")

    # fix quotes
    text = text.replace("“", "\"")
    text = text.replace("”", "\"")

    # Replace any capital letter at the start of a word with ^ followed by the lowercase letter
    text = re.sub(r"(?<![a-zA-Z])([A-Z])", lambda match: f"^{match.group(0).lower()}", text)

    # Replace all other capital letters with lowercase
    text = re.sub(r"([A-Z])", lambda match: f"{match.group(0).lower()}", text)

    # Remove duplicate whitespace
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"\n+", "\n", text)
    text = re.sub(r"\t+", "\t", text)

    # Replace whitespace characters with special words
    text = re.sub(r"(\t)", r" zztabzz ", text)
    text = re.sub(r"(\n)", r" zznewlinezz ", text)
    text = re.sub(r"(\s)", r" zzspacezz ", text)

    # Split before and after punctuation
    for punctuation in string.punctuation:
        text = text.replace(punctuation, f" {punctuation} ")

    return text

# %%
def postprocess_text(text):

    # Replace special words with whitespace characters
    text = text.replace("zztabzz", "\t")
    text = text.replace("zznewlinezz", "\n")
    text = text.replace("zzspacezz", " ")

    # Remake capital letters at beginning of words
    text = re.sub(r"\^([a-z])", lambda match: f"{match.group(1).upper()}", text)

    text = text.replace("^", "")

    return text

# %%
# def getMyText():
#   path_to_file = tf.keras.utils.get_file('austen.txt', 'https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/austen/austen.txt')

#   text = open(path_to_file, 'rb').read().decode(encoding='utf-8')

#   # path_to_file = tf.keras.utils.get_file('903-0.txt', 'https://www.gutenberg.org/files/903/903-0.txt')
#   # author_text += open(path_to_file, 'rb').read().decode(encoding='utf-8')[2999:-19194]
#   # tf.io.gfile.remove(path_to_file)

#   return preprocess_text(text)

import os
import tensorflow as tf

def getMyText():
    file_name = 'chaos1.txt'
    file_url = 'https://raw.githubusercontent.com/Jacobc246/files/refs/heads/main/chaos1.txt'
    local_dir = 'saved_files'  # Directory to save the file
    local_path = os.path.join(local_dir, file_name)

    try:
        # Ensure the directory exists
        if not os.path.exists(local_dir):
            os.makedirs(local_dir)

        # Check if the file exists locally
        if os.path.exists(local_path):
            print(f"File '{file_name}' found locally. Using it.")
        else:
            print(f"File '{file_name}' not found locally. Downloading it.")
            # Download the file
            downloaded_path = tf.keras.utils.get_file(file_name, file_url)

            # Save the downloaded file to the designated local directory
            with open(downloaded_path, 'rb') as source_file:
                with open(local_path, 'wb') as dest_file:
                    dest_file.write(source_file.read())

        # Read the file's contents
        with open(local_path, 'rb') as file:
            text = file.read().decode(encoding='utf-8')

        return preprocess_text(text)

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
getMyText()
# Out:
# File 'chaos1.txt' not found locally. Downloading it.
# ' ^ child zzspacezz of zzspacezz the zzspacezz pure zzspacezz unclouded zzspacezz brow zzspacezz  ^ and zzspacezz dreaming zzspacezz eyes zzspacezz of zzspacezz wonder !  zzspacezz  ^ though zzspacezz time zzspacezz be zzspacezz fleet ,  zzspacezz and zzspacezz  ^ i zzspacezz and zzspacezz thou zzspacezz  ^ are zzspacezz half zzspacezz a zzspacezz life zzspacezz asunder ,  zzspacezz  ^ thy zzspacezz loving zzspacezz smile zzspacezz will zzspacezz surely zzspacezz hail zzspacezz  ^ the zzspacezz love - gift zzspacezz of zzspacezz a zzspacezz fairy - tale .  zzspacezz  ^ i zzspacezz have zzspacezz not zzspacezz seen zzspacezz thy zzspacezz sunny zzspacezz face ,  zzspacezz  ^ nor zzspacezz heard zzspacezz thy zzspacezz silver zzspacezz laughter ;  zzspacezz  ^ no zzspacezz thought zzspacezz of zzspacezz me zzspacezz shall zzspacezz find zzspacezz a zzspacezz place zzspacezz  ^ in zzspacezz thy zzspacezz young zzspacezz life’s zzspacezz hereafter— zzspacezz  ^ enough zzspacezz that zzspacezz now zzspacezz thou zzspacezz wilt zzspacezz not zzspacezz fail zzspacezz  ^ to zzspacezz listen zzspacezz to zzspacezz my zzspacezz fairy - tale .  zzspacezz  ^ a zzspacezz tale zzspacezz begun zzspacezz in zzspacezz other zzspacezz days ,  zzspacezz  ^ when zzspacezz summer zzspacezz suns zzspacezz were zzspacezz glowing— zzspacezz  ^ a zzspacezz simple zzspacezz chime ,  zzspacezz that zzspacezz served zzspacezz to zzspacezz time zzspacezz  ^ the zzspacezz rhythm zzspacezz of zzspacezz oar zzspacezz rowing— zzspacezz  ^ whose zzspacezz echoes zzspacezz live zzspacezz in zzspacezz memory zzspacezz yet ,  zzspacezz  ^ though zzspacezz envious zzspacezz years zzspacezz would zzspacezz say zzspacezz ‘forget . ’ zzspacezz  ^ come ,  zzspacezz hearken zzspacezz then ,  zzspacezz ere zzspacezz voice zzspacezz of zzspacezz dread .  zzspacezz  ^ with zzspacezz bitter zzspacezz tidings zzspacezz laden ,  zzspacezz  ^ shall zzspacezz summon zzspacezz to zzspacezz unwelcome zzspacezz bed zzspacezz  ^ a zzspacezz melancholy zzspacezz maiden !  zzspacezz  ^ we zzspacezz are zzspacezz but zzspacezz older zzspacezz children ,  zzspacezz dear ,  zzspacezz  ^ who zzspacezz fret zzspacezz to zzspacezz find zzspacezz our zzspacezz bedtime zzspacezz near .  zzspacezz  ^ without ,  zzspacezz the zzspacezz frost ,  zzspacezz the zzspacezz blinding zzspacezz snow .  zzspacezz  ^ the zzspacezz storm - wind’s zzspacezz moody zzspacezz madness— zzspacezz  ^ within ,  zzspacezz the zzspacezz firelight’s zzspacezz ruddy zzspacezz glow ,  zzspacezz  ^ and zzspacezz childhood’s zzspacezz nest zzspacezz of zzspacezz gladness .  zzspacezz  ^ the zzspacezz magic zzspacezz words zzspacezz shall zzspacezz hold zzspacezz thee zzspacezz fast :  zzspacezz  ^ thou zzspacezz shalt zzspacezz not zzspacezz heed zzspacezz the zzspacezz raving zzspacezz blast .  zzspacezz  ^ and zzspacezz though zzspacezz the zzspacezz shadow zzspacezz of zzspacezz a zzspacezz sigh zzspacezz  ^ may zzspacezz tremble zzspacezz through zzspacezz the zzspacezz story ,  zzspacezz  ^ for zzspacezz ‘happy zzspacezz summer zzspacezz days’ zzspacezz gone zzspacezz by ,  zzspacezz  ^ and zzspacezz vanish’d zzspacezz summer zzspacezz glory— zzspacezz  ^ it zzspacezz shall zzspacezz not zzspacezz touch zzspacezz with zzspacezz breath zzspacezz of zzspacezz bale zzspacezz  ^ the zzspacezz pleasance zzspacezz of zzspacezz our zzspacezz fairy - tale .  zzspacezz  ^ chapter zzspacezz  ^ i .  zzspacezz  ^ looking -  ^ glass zzspacezz house zzspacezz  ^ one zzspacezz thing zzspacezz was zzspacezz certain ,  zzspacezz that zzspacezz the zzspacezz  _ white _  zzspacezz kitten zzspacezz had zzspacezz had zzspacezz nothing zzspacezz to zzspacezz do zzspacezz with zzspacezz it : —it zzspacezz was zzspacezz the zzspacezz black zzspacezz kitten’s zzspacezz fault zzspacezz entirely .  zzspacezz  ^ for zzspacezz the zzspacezz white zzspacezz kitten zzspacezz had zzspacezz been zzspacezz having zzspacezz its zzspacezz face zzsp ...

# %%
def getRandomText(numbooks = 1, verbose=False):
  download_log = io.StringIO()
  text_random = ''
  for b in range(numbooks):
    foundbook = False
    while(foundbook == False):
      booknum = random.randint(100,60000)
      if verbose:
        print('Trying Book #: ',booknum)
      if random.random() > 0.5:
        url = 'https://www.gutenberg.org/files/' + str(booknum) + '/' + str(booknum) + '-0.txt'
        filename_temp = str(booknum) + '-0.txt'
      else:
        url = 'https://www.gutenberg.org/cache/epub/' + str(booknum) + '/pg' + str(booknum) + '.txt'
        filename_temp = 'pg' + str(booknum) + '.txt'
      if verbose:
        print('Trying: ', url)
      try:
        if verbose:
          path_to_file_temp = tf.keras.utils.get_file(filename_temp, url)
        else:
          with contextlib.redirect_stdout(download_log):
            path_to_file_temp = tf.keras.utils.get_file(filename_temp, url)
        temptext = open(path_to_file_temp, 'rb').read().decode(encoding='utf-8')
        tf.io.gfile.remove(path_to_file_temp)
        if (temptext.find('Language: English') >= 0):
          offset = random.randint(-20,20)
          header = 2000
          total_length = 200000
          chopoffend = 10000
          if len(temptext) > (header+total_length+offset+chopoffend):
            foundbook = True
            text_random += temptext[header+offset:header+total_length+offset]
            #print("Yes: " + str(booknum))
            if verbose:
              print('New size of dataset: ', len(text_random))
          elif len(temptext) > (header+12000):
            foundbook = True
            text_random += temptext[header:-chopoffend]
            #print("Yes (smaller): " + str(booknum))
            if verbose:
              print('New size of dataset: ', len(text_random))
          else:
            if verbose:
              print('Not long enough. Trying again...')
            #print("No: " + str(booknum) + " too short")
        else:
          if verbose:
            print('Not English. Trying again...')
          #print("No: " + str(booknum) + " not English")
        del temptext
      except:
        if verbose:
          print('Not valid file. Trying again...')
        #print("No: " + str(booknum) + " not valid")
        foundbook = False
    if verbose:
      print("Found " + str(b+1) + " books so far...")
  del download_log
  #text_random = "".join(c for c in text_random if c in vocab)
  #all_ids_random = ids_from_chars(tf.strings.unicode_split(text_random, 'UTF-8'))
  #ids_dataset_random = tf.data.Dataset.from_tensor_slices(all_ids_random)
  #sequences_random = ids_dataset_random.batch(seq_length+1, drop_remainder=True)
  #dataset_random = sequences_random.map(split_input_target)
  #dataset_random = (dataset_random.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True).prefetch(tf.data.experimental.AUTOTUNE))
  #return dataset_random
  return preprocess_text(text_random)

# %%
if restart:
  vocab_text = getMyText()
# Out:
# File 'chaos1.txt' found locally. Using it.

# %% [markdown]
# Make vocabulary (Adapted from TensorFlow word embedding tutorial)
#
# ---

# %%
# Vocabulary size and number of words in a sequence.
vocab_size = 4096
sequence_length = 128

# %%
if restart:
  # Use the text vectorization layer to normalize, split, and map strings to
  # integers. Note that the layer uses the custom standardization defined above.
  # Set maximum_sequence length as all samples are not of the same length.
  vectorize_layer = TextVectorization(
      standardize='lower',
      split='whitespace',
      max_tokens=vocab_size,
      output_mode='int',
      #output_sequence_length=sequence_length
      )

# %%
if restart:
  # Make a text-only dataset (no labels) and call adapt to build the vocabulary.
  vectorize_layer.adapt([vocab_text])

# %%
if restart:
  vocabulary = vectorize_layer.get_vocabulary()

# %% [markdown]
# Save Vocabulary

# %%
if restart:
  with open(path + "vocabulary.txt", "w") as file:
    for word in vocabulary:
        file.write(word + "\n")

# %% [markdown]
# Load Saved Vocabulary

# %%
if restart == False:
  with open(path + "vocabulary.txt", "r") as file:
      vocabulary = [word.strip() for word in file.readlines()]
      vocabulary = vocabulary

  vectorize_layer = TextVectorization(
      vocabulary=vocabulary,
      standardize='lower',
      split='whitespace',
      max_tokens=vocab_size,
      output_mode='int',
      #output_sequence_length=sequence_length
      )

# %%
print(vocabulary[:20])
print(vocabulary[-20:])
# Out:
# ['', '[UNK]', np.str_('zzspacezz'), np.str_('^'), np.str_(','), np.str_('"'), np.str_('.'), np.str_('the'), np.str_('and'), np.str_('to'), np.str_('a'), np.str_('_'), np.str_('it'), np.str_('said'), np.str_('i'), np.str_('-'), np.str_("'"), np.str_('of'), np.str_('he'), np.str_('you')]
# [np.str_('scour'), np.str_('scornful'), np.str_('scolding'), np.str_('scold'), np.str_('schoolroom'), np.str_('schoolboys'), np.str_('sceptre'), np.str_('scampering'), np.str_('scaly'), np.str_('scale'), np.str_('say—‘'), np.str_('say—that’s'), np.str_('sawt’'), np.str_('sawing'), np.str_('sawdust'), np.str_('savings'), np.str_('saving'), np.str_('sauntered'), np.str_('saucepans'), np.str_('sarcastic')]

# %% [markdown]
# Turn text into a dataset

# %%
# This function will generate our sequence pairs:
def split_input_target(sequence):
    input_ids = sequence[:-1]
    target_ids = sequence[1:]
    return input_ids, target_ids

# This function will create the dataset
def text_to_dataset(text):
  all_ids = vectorize_layer(text)
  ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)
  del all_ids
  sequences = ids_dataset.batch(sequence_length+1, drop_remainder=True)
  del ids_dataset

  # Call the function for every sequence in our list to create a new dataset
  # of input->target pairs
  dataset = sequences.map(split_input_target)
  del sequences

  # shuffle


  return dataset

# %% [markdown]
# Test on vocab text

# %%
if restart:
  vocab_ds = text_to_dataset(vocab_text)

# %%
def text_from_ids(ids):
  text = ''.join([vocabulary[index] for index in ids])
  return postprocess_text(text)

vocabulary_adjusted = vocabulary
vocabulary_adjusted[0] = '[UNK]'
vocabulary_adjusted[1] = ''

words_from_ids = tf.keras.layers.StringLookup(vocabulary=vocabulary_adjusted, invert=True)

# %%
if restart:
  for input_example, target_example in vocab_ds.take(1):
    print("Input: ")
    print(input_example)
    print(text_from_ids(input_example))
    print(words_from_ids(input_example))
    print("Target: ")
    print(target_example)
    print(text_from_ids(target_example))
# Out:
# Input:
# tf.Tensor(
# [   3  542    2   17    2    7    2    1    2 3584    2 3248    2    3
#     8    2  861    2  217    2   17    2  289   21    2    3  369    2
#    91    2   45    2    1    4    2    8    2    3   14    2    8    2
#  1311    2    3   81    2  268    2   10    2  446    2    1    4    2
#     3 1600    2 2302    2  938    2  153    2 3793    2    1    2    3
#     7    2  710   15    1    2   17    2   10    2 2014   15  876    6
#     2    3   14    2   63    2   59    2  292    2 1600    2 1212    2
#   361    4    2    3 1243    2  237    2 1600    2 2199    2 2315   52
#     2    3   85    2   67    2   17    2   64    2  174    2  208    2
#    10    2], shape=(128,), dtype=int64)
# Child of the  unclouded brow And dreaming eyes of wonder! Though time be , and I and thou Are half a life , Thy loving smile will surely  The love- of a fairy-tale. I have not seen thy sunny face, Nor heard thy silver laughter; No thought of me shall find a
# tf.Tensor(
# [b'^' b'child' b'zzspacezz' b'of' b'zzspacezz' b'the' b'zzspacezz' b''
#  b'zzspacezz' b'unclouded' b'zzspacezz' b'brow' b'zzspacezz' b'^' b'and'
#  b'zzspacezz' b'dreaming' b'zzspacezz' b'eyes' b'zzspacezz' b'of'
#  b'zzspacezz' b'wonder' b'!' b'zzspacezz' b'^' b'though' b'zzspacezz'
#  b'time' b'zzspacezz' b'be' b'zzspacezz' b'' b',' b'zzspacezz' b'and'
#  b'zzspacezz' b'^' b'i' b'zzspacezz' b'and' b'zzspacezz' b'thou'
#  b'zzspacezz' b'^' b'are' b'zzspacezz' b'half' b'zzspacezz' b'a'
#  b'zzspacezz' b'life' b'zzspacezz' b'' b',' b'zzspacezz' b'^' b'thy'
#  b'zzspacezz' b'loving' b'zzspacezz' b'smile' b'zzspacezz' b'will'
#  b'zzspacezz' b'surely' b'zzspacezz' b'' b'zzspacezz' b'^' b'the'
#  b'zzspacezz' b'love' b'-' b'' b'zzspacezz' b'of' b'zzspacezz' b'a'
#  b'zzspacezz' b'fairy' b'-' b'tale' b'.' b'zzspacezz' b'^' b'i'
#  b'zzspacezz' b'have' b'zzspacezz' b'not' b'zzspacezz' b'seen'
#  b'zzspacezz' b'thy' b'zzspacezz' b'sunny' b'zzspacezz' b'face' b','
#  b'zzspacezz' b'^' b'nor' b'zzspacezz' b'heard' b'zzspacezz' b'thy'
#  b'zzspacezz' b'silver' b'zzspacezz' b'laughter' b';' b'zzspacezz' b'^'
#  b'no' b'zzspacezz' b'thought' b'zzspacezz' b'of' b'zzspacezz' b'me'
#  b'zzspacezz' b'shall' b'zzspacezz' b'find' b'zzspacezz' b'a' b'zzspacezz'], shape=(128,), dtype=string)
# Target:
# tf.Tensor(
# [ 542    2   17    2    7    2    1    2 3584    2 3248    2    3    8
#     2  861    2  217    2   17    2  289   21    2    3  369    2   91
#     2   45    2    1    4    2    8    2    3   14    2    8    2 1311
#     2    3   81    2  268    2   10    2  446    2    1    4    2    3
#  1600    2 2302    2  938    2  153    2 3793    2    1    2    3    7
#     2  710   15    1    2   17    2   10    2 2014   15  876    6    2
#     3   14    2   63    2   59    2  292    2 1600    2 1212    2  361
#     4    2    3 1243    2  237    2 1600    2 2199    2 2315   52    2
#     3   85    2   67    2   17    2   64    2  174    2  208    2   10
#     2  266], shape=(128,), dtype=int64)
# child of the  unclouded brow And dreaming eyes of wonder! Though time be , and I and thou Are half a life , Thy loving smile will surely  The love- of a fairy-tale. I have not seen thy sunny face, Nor heard thy silver laughter; No thought of me shall find a place

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 10000

def setup_dataset(dataset):
  dataset = (
    dataset
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE, drop_remainder=True)
    .prefetch(tf.data.experimental.AUTOTUNE))
  return dataset

# %%
if restart:
  vocab_ds = setup_dataset(vocab_ds)

# %% [markdown]
# ## III. Build the model
#
# Next, we'll build our model. Up until this point, you've been using the Keras symbolic, or imperative API for creating your models. Doing something like:
#
#     model = tf.keras.models.Sequentla()
#     model.add(tf.keras.layers.Dense(80, activation='relu))
#     etc...
#
# However, tensorflow has another way to build models called the Functional API, which gives us a lot more control over what happens inside the model. You can read more about [the differences and when to use each here](https://blog.tensorflow.org/2019/01/what-are-symbolic-and-imperative-apis.html).
#
# We'll use the functional API for our RNN in this example. This will involve defining our model as a custom subclass of `tf.keras.Model`.
#
# If you're not familiar with classes in python, you might want to review [this quick tutorial](https://www.w3schools.com/python/python_classes.asp), as well as [this one on class inheritance](https://www.w3schools.com/python/python_inheritance.asp).
#
# Using a functional model is important for our situation because we're not just training it to predict a single character for a single sequence, but as we make predictions with it, we need it to remember those predictions as use that memory as it makes new predictions.

# %%
# Create our custom model. Given a sequence of characters, this
# model's job is to predict what character should come next.
class AustenTextModel(tf.keras.Model):

  # This is our class constructor method, it will be executed when
  # we first create an instance of the class
  def __init__(self, vocab_size, embedding_dim, rnn_units):
    super().__init__()

    # Our model will have three layers:

    # 1. An embedding layer that handles the encoding of our vocabulary into
    #    a vector of values suitable for a neural network
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

    # 2. A GRU layer that handles the "memory" aspects of our RNN. If you're
    #    wondering why we use GRU instead of LSTM, and whether LSTM is better,
    #    take a look at this article: https://datascience.stackexchange.com/questions/14581/when-to-use-gru-over-lstm
    #    then consider trying out LSTM instead (or in addition to!)
    #self.gru = tf.keras.layers.GRU(rnn_units, return_sequences=True, return_state=True)
    self.lstm1 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm2 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    self.lstm3 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
    #self.lstm4 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)


    self.hidden1 = tf.keras.layers.Dense(embedding_dim*64, activation='relu')
    self.hidden2 = tf.keras.layers.Dense(embedding_dim*16, activation='relu')
    #self.hidden3 = tf.keras.layers.Dense(embedding_dim*4, activation='relu')

    # 3. Our output layer that will give us a set of probabilities for each
    #    character in our vocabulary.
    self.dense = tf.keras.layers.Dense(vocab_size)

  # This function will be executed for each epoch of our training. Here
  # we will manually feed information from one layer of our network to the
  # next.
  def call(self, inputs, states=None, return_state=False, training=False):
    x = inputs

    # 1. Feed the inputs into the embedding layer, and tell it if we are
    #    training or predicting
    x = self.embedding(x, training=training)

    # 2. If we don't have any state in memory yet, get the initial random state
    #    from our GRUI layer.
    batch_size = tf.shape(inputs)[0]

    if states is None:
      states1 = [tf.zeros([batch_size, self.lstm1.units]), tf.zeros([batch_size, self.lstm1.units])]
      states2 = [tf.zeros([batch_size, self.lstm2.units]), tf.zeros([batch_size, self.lstm2.units])]
      states3 = [tf.zeros([batch_size, self.lstm3.units]), tf.zeros([batch_size, self.lstm3.units])]
      #states4 = [tf.zeros([batch_size, self.lstm4.units]), tf.zeros([batch_size, self.lstm4.units])]
    else:
      states1 = states[0]
      states2 = states[1]
      states3 = states[2]
      #states4 = states[3]
    # 3. Now, feed the vectorized input along with the current state of memory
    #    into the gru layer.
    x, state_h_1, state_c_1 = self.lstm1(x, initial_state=states1, training=training)
    states_out_1 = [state_h_1,state_c_1]

    x, state_h_2, state_c_2 = self.lstm2(x, initial_state=states2, training=training)
    states_out_2 = [state_h_2,state_c_2]

    x, state_h_3, state_c_3 = self.lstm3(x, initial_state=states3, training=training)
    states_out_3 = [state_h_3,state_c_3]

    #x, state_h_4, state_c_4 = self.lstm4(x, initial_state=states4, training=training)
    #states_out_4 = [state_h_4,state_c_4]

    states_out = [states_out_1, states_out_2, states_out_3]#, states_out_4]
    #states_out = [states_out_1, states_out_2]

    x = self.hidden1(x,training=training)
    x = self.hidden2(x,training=training)
    #x = self.hidden3(x,training=training)
    # 4. Finally, pass the results on to the dense layer
    x = self.dense(x, training=training)

    # 5. Return the results
    if return_state:
      return x, states_out
    else:
      return x

# %%
class AustenTextModel(tf.keras.Model):

    def __init__(self, vocab_size, embedding_dim, rnn_units, dropout_rate=0.2):
        super().__init__()

        # Embedding layer
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)

        # LSTM layers
        self.lstm1 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
        self.lstm2 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)
        self.lstm3 = tf.keras.layers.LSTM(rnn_units, return_sequences=True, return_state=True)

        # Dropout after LSTM layers
        self.dropout_lstm1 = tf.keras.layers.Dropout(dropout_rate)
        self.dropout_lstm2 = tf.keras.layers.Dropout(dropout_rate)
        self.dropout_lstm3 = tf.keras.layers.Dropout(dropout_rate)

        # Hidden layers
        self.hidden1 = tf.keras.layers.Dense(embedding_dim * 64, activation='relu')
        self.hidden2 = tf.keras.layers.Dense(embedding_dim * 16, activation='relu')

        # Dropout after Dense layers
        self.dropout_dense1 = tf.keras.layers.Dropout(dropout_rate)
        self.dropout_dense2 = tf.keras.layers.Dropout(dropout_rate)

        # Output layer
        self.dense = tf.keras.layers.Dense(vocab_size)

    def call(self, inputs, states=None, return_state=False, training=False):
        x = inputs

        # Embedding layer
        x = self.embedding(x, training=training)

        # Initialize states if not provided
        batch_size = tf.shape(inputs)[0]
        if states is None:
            states1 = [tf.zeros([batch_size, self.lstm1.units]), tf.zeros([batch_size, self.lstm1.units])]
            states2 = [tf.zeros([batch_size, self.lstm2.units]), tf.zeros([batch_size, self.lstm2.units])]
            states3 = [tf.zeros([batch_size, self.lstm3.units]), tf.zeros([batch_size, self.lstm3.units])]
        else:
            states1 = states[0]
            states2 = states[1]
            states3 = states[2]

        # LSTM layers with dropout
        x, state_h_1, state_c_1 = self.lstm1(x, initial_state=states1, training=training)
        x = self.dropout_lstm1(x, training=training)
        states_out_1 = [state_h_1, state_c_1]

        x, state_h_2, state_c_2 = self.lstm2(x, initial_state=states2, training=training)
        x = self.dropout_lstm2(x, training=training)
        states_out_2 = [state_h_2, state_c_2]

        x, state_h_3, state_c_3 = self.lstm3(x, initial_state=states3, training=training)
        x = self.dropout_lstm3(x, training=training)
        states_out_3 = [state_h_3, state_c_3]

        states_out = [states_out_1, states_out_2, states_out_3]

        # Dense layers with dropout
        x = self.hidden1(x, training=training)
        x = self.dropout_dense1(x, training=training)

        x = self.hidden2(x, training=training)
        x = self.dropout_dense2(x, training=training)

        # Output layer
        x = self.dense(x, training=training)

        if return_state:
            return x, states_out
        else:
            return x

# %%
if restart:
  dataset = vocab_ds
  del vocab_text
  del vocab_ds
else:
  new_text = getRandomText(numbooks = 10)
  dataset = text_to_dataset(new_text)
  del new_text
  dataset = setup_dataset(dataset)

# %%
# Create an instance of our model
#vocab_size=len(ids_from_chars.get_vocabulary())
embedding_dim = 128
rnn_units = 512

model = AustenTextModel(vocab_size, embedding_dim, rnn_units)

# %%
# Verify the output of our model is correct by running one sample through
# This will also compile the model for us. This step will take a bit.
for input_example_batch, target_example_batch in dataset.take(1):
    example_batch_predictions = model(input_example_batch)
    print(example_batch_predictions.shape, "# (batch_size, sequence_length, vocab_size)")
# Out:
# (64, 128, 4096) # (batch_size, sequence_length, vocab_size)

# %%
# Now let's view the model summary
model.summary()
# Out:
# Model: "austen_text_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (64, 128, 128)              │         524,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ((64, 128, 512), (64, 512), │       1,312,768 │
# │                                      │ (64, 512))                  │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ ((64, 128, 512), (64, 512), │       2,099,200 │
# │                                      │ (64, 512))                  │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ ((64, 128, 512), (64, 512), │       2,099,200 │
# │                                      │ (64, 512))                  │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (64, 128, 8192)             │       4,202,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (64, 128, 2048)             │      16,779,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (64, 128, 4096)             │       8,392,704 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 35,409,920 (135.08 MB)
#  Trainable params: 35,409,920 (135.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Here's the code we'll use to sample for us. It has some extra steps to apply
# the temperature to the distribution, and to make sure we don't get empty
# characters in our text. Most importantly, it will keep track of our model
# state for us.

class OneStep(tf.keras.Model):
  def __init__(self, model, vectorize_layer, vocabulary, temperature=1):
    super().__init__()
    self.temperature=temperature
    self.model = model
    self.vectorize_layer = vectorize_layer
    self.vocabulary = vocabulary
    #print("initialized")

    # Create a mask to prevent "" or "[UNK]" from being generated.
    skip_ids = StringLookup(vocabulary=list(vocabulary))(['', '[UNK]'])[:, None]
    #print(skip_ids)
    #print("3")
    sparse_mask = tf.SparseTensor(
        # Put a -inf at each bad index.
        values=[-float('inf')]*len(skip_ids),
        indices = skip_ids,
        # Match the shape to the vocabulary
        dense_shape=[len(vocabulary)])
    #print("4")
    self.prediction_mask = tf.sparse.to_dense(sparse_mask,validate_indices=False)
    #print("5")

  @tf.function
  def generate_one_step(self, inputs, states=None):
    # Convert strings to token IDs.
    #input_chars = tf.strings.unicode_split(inputs, 'UTF-8')
    input_ids = self.vectorize_layer(inputs)
    #print(input_ids)

    # Run the model.
    # predicted_logits.shape is [batch, char, next_char_logits]
    predicted_logits, states =  self.model(inputs=input_ids, states=states,
                                          return_state=True)
    del input_ids
    # Only use the last prediction.
    predicted_logits = predicted_logits[:, -1, :]
    predicted_logits = predicted_logits/self.temperature

    # Apply the prediction mask: prevent "" or "[UNK]" from being generated.
    predicted_logits = predicted_logits + self.prediction_mask

    # Sample the output logits to generate token IDs.
    predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
    del predicted_logits
    predicted_ids = tf.squeeze(predicted_ids, axis=-1)

    #print(predicted_ids[0])

    # Return the characters and model state.
    return words_from_ids(predicted_ids), states

# %%
def produce_sample(model, vectorize_layer, vocabulary, temp, epoch, prompt):
  # Create an instance of the character generator
  #print("entered")
  one_step_model = OneStep(model, vectorize_layer, vocabulary, temp)
  #print("rand one step")
  # Now, let's generate a 1000 character chapter by giving our model "Chapter 1"
  # as its starting text
  states = None
  next_char = tf.constant([preprocess_text(prompt)])
  result = [tf.constant([prompt])]

  for n in range(200):
    next_char, states = one_step_model.generate_one_step(next_char, states=states)
    #print(next_char)
    result.append(next_char)
    #print(result)

  result = tf.strings.join(result)
  #print(result)

  # Print the results formatted.
  #print('Temp: ' + str(temp) + '\n')
  print(postprocess_text(result[0].numpy().decode('utf-8')))
  #print('\n\n')
  print('Epoch: ' + str(epoch) + '\n', file=open(path + 'tree.txt', 'a'))
  print('Temp: ' + str(temp) + '\n', file=open(path + 'tree.txt', 'a'))
  print(postprocess_text(result[0].numpy().decode('utf-8')), file=open(path + 'tree.txt', 'a'))
  print('\n\n', file=open(path + 'tree.txt', 'a'))
  del states
  del next_char
  del result

# %% [markdown]
# ## IV. Train the model
#
# For our purposes, we'll be using [categorical cross entropy](https://machinelearningmastery.com/cross-entropy-for-machine-learning/) as our loss function*. Also, our model will be outputting ["logits" rather than normalized probabilities](https://stackoverflow.com/questions/41455101/what-is-the-meaning-of-the-word-logits-in-tensorflow), because we'll be doing further transformations on the output later.
#
#
# \* Note that since our model deals with integer encoding rather than one-hot encoding, we'll specifically be using [sparse categorical cross entropy](https://stats.stackexchange.com/questions/326065/cross-entropy-vs-sparse-cross-entropy-when-to-use-one-over-the-other).

# %%
# sherlock_text = getMyText()
# Out:
# File 'austen.txt' found locally. Using it.

# %%
if restart == False:
  model.load_weights(path + "lstm_gru_SH_modelweights_fall2023-random_urls.h5")

# %%
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
opt = tf.keras.optimizers.Adam(learning_rate=0.002)
model.compile(optimizer=opt, loss=loss)

num_epochs_total = 50
if restart:
  start_epoch = 0
else:
  start_epoch = epoch_to_pickup
for e in range(start_epoch, num_epochs_total):
  success = False
  while(success == False):
    try:
      print("epoch: ", e)
      # if e < 50:
      #   new_text = getRandomText(numbooks = 20)
      # else:
      #   new_text = sherlock_text + getRandomText(numbooks = (num_epochs_total - e)//10)
      new_text = getMyText()
      dataset = text_to_dataset(new_text)
      del new_text
      dataset = setup_dataset(dataset)
      #opt = tf.keras.optimizers.Adam(learning_rate=0.002*(0.97**e))
      #model.compile(optimizer=opt, loss=loss)
      model.optimizer.learning_rate.assign(0.002*(0.99**e))
      model.fit(dataset, epochs=1, verbose=1)
      print("finished training...")
      del dataset
      #print("saving weights...")
      #model.save_weights(path + "lstm_gru_SH_modelweights_fall2023-random_urls.h5")
      #print("weights saved...")
      for temp in [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]:
        produce_sample(model,vectorize_layer,vocabulary, temp, e, 'The world seemed like such a peaceful place until the magic tree was discovered in London.')
      print("samples produced...")
      gc.collect()
      print("garbage collected...")
      tf.keras.backend.clear_session()
      print("session cleared (to save memory)...")
      #tf.config.experimental.reset_all()
      success = True
    except:
      gc.collect()
      tf.keras.backend.clear_session()
      #tf.config.experimental.reset_all()
      try:
        del dataset
      except:
        print("dataset already deleted")
      print("retrying epoch: " , e)
# Out:
# epoch:  0
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 24s 580ms/step - loss: 1.7178
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. It was a Very Small Animal, and Pooh and Rabbit Piglet was sitting on the Hundred Acre Wood and Piglet to Pooh and Piglet and Piglet to Piglet, and Kanga said to himself, "I think it is. I didn't want to be a Cunning Trap. I can see what I was, and I can see what I was going to do." "I thought I was saying to Christopher Robin," said Christopher Robin. "That will be a
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was a little anxious about two in the air as he could do. The Queen was sitting on the room with her head through the wood, and began at the corners scented rushes, and behind them in the middle of the worsted a hug, and a bright silvery mist, and then in the beautiful days of the party began sneezing, and the soup rolled wildly up into the air, and would not like a subject of authority over the March Hare, sitting on a corner, and the Queen went on with
# The world seemed like such a peaceful place until the magic tree was discovered in London. And I have a Very Small and Sorry Tigger underneath too, and I think we are swim. I think I am a Good Thing. I haven't got a pocket, or it, and I've got a Very Small Animal. I haven't got doing and one of the string." "Well," said Piglet. "I just wondered what I thought, was going to fall." "He was a _good_ girl," said Eeyore. "It isn't Brain, and
# The world seemed like such a peaceful place until the magic tree was discovered in London. And he was still patiently (And not a Bear, when he felt not the wrong sort of funny, I am going bigger. And then, having had a sort of look of the story, And I saw a Heffalump to be getting a Long Introduction, and I think I am a Friendly Idea. There was Two Past Which Would Piglet One Again Pooh And And I go to Don. I am God and, and I've found him at the others
# The world seemed like such a peaceful place until the magic tree was discovered in London. And round them and snows, and the big Tigger. He ran out to scour the story when you hadn't had a Bear, and Piglet and Piglet came Counting An Bear, an old sailor sort of swallow of some. And it was a red one of this place and relations came to Pooh's house. He had got into the door in the Forest with it out of the snow, and wondering whether he had been explained to Tigger and in the morning again, because he had a sort
# The world seemed like such a peaceful place until the magic tree was discovered in London. "If it was a little piece of them on, Tigger." "It is so more," said Rabbit. Piglet jumped up and down to Piglet. Christopher Robin was sitting round at himself, as he walked back to the ground, and feeling the soup, just as it came home, thinking Rabbit said that he was just going back again a Knight to Kanga, as he walked home before that he was in another trap for him. He had got to the interesting place, and Piglet was nudging Christopher
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  1
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 604ms/step - loss: 1.3425
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. He is easy to do what I could get any fatter, and I don't know where I mean, and I don't know anything. It was a Contradiction is looking for a Heffalump to be Me. He was still going to the bridge, and Piglet could escape by Eeyore's house, and Pooh was sitting on the ground and on the ground, and stayed in circles and Roo seemed to be Useful during the Forest by the Forest, and then he had explained that he hadn'
# The world seemed like such a peaceful place until the magic tree was discovered in London. Oh, Daddy is clever I know I should think—and you get I am?" And he began to eat Tigger a little rest, and then he said "Yes," and then he said, "I must go out again, I shall be able to be miserable that would we go to me. It's a nice Outdoor Song. One of those time to begin _me_." So he trotted on with the mist in the middle of the Forest; and Pooh and Piglet walked on singing
# The world seemed like such a peaceful place until the magic tree was discovered in London. The Little Black Hen Looked at the Nursery Their still watch keep And years and hides him, And bounced and fell along And kissed him lots; And the wheels was clean than Was in a sieve. And these young he stood and propped the armour spread through the wine— Lingering the Knight Of Hearts, and all that Alice told her together, and had just succeeded with one of her own children, that came on a week or two. The Lion looked very angry for the water
# The world seemed like such a peaceful place until the magic tree was discovered in London. Holl, I wonder how it's going to know about it. Do you think you're going to _look_ like a little trouble?" "Yes, Pooh," said Eeyore. "Oh, Eeyore, I didn't know I should think," said Tigger, "is I am I," and he said that, Tigger didn't think of something else. And a Friendly Pooh Discovered Floated Eeyore Pooh was nudging him. He thought that perhaps he had gone a _little_ honey to do
# The world seemed like such a peaceful place until the magic tree was discovered in London. This warm tweedledee with ninety-times-three, And we gave me a sweet or so, And just as he sneezes, He could not touch the fly) It was very well to be more him. It was the sort of bread of the day I make me getting on Tattoo, And he managed to write And sneezles And Two-Here Of Little Bears That Trespassers W. James was thinking to a Heffalump of A Grand Thing muddled his Twice Times One-- But
# The world seemed like such a peaceful place until the magic tree was discovered in London. Which is easy because they are practising.' They saw this song. The Knight Whose Armour Which the Bear were none of the Waiting of a funny-hand.... And they've been standing on the top of the stream to see. "That I am not quite be anybody right," said Rabbit, after a long silence and put it away. "If I have said it a Cunning Trap, and he had no honey to play to the special bridge, and then he'll come up-
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  2
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 583ms/step - loss: 1.2898
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. She had once seen it out of the wood, and the Queen was talking together, and she was surprised to find herself sitting on the stairs, and the Knight came into the other side, and the Queen clutched wildly the Queen, and the Queen clutched wildly into its face and seized the heap of rushes, and the choking divided into the dish of crawling her and shady, "I feel like the look size, and oh, if you don’t see one alive, compared with their eye as if you understood I
# The world seemed like such a peaceful place until the magic tree was discovered in London. And when I were Emperors, And Pooh and Piglet were sitting on the Hundred Acre Wood and said "B, Tigger, Violets," and in jumped in the middle of the stream, and Pooh was saying that he would go and see the whole Trap, and then he got up together again and put it out of it. And Roo fell on his back of the Gravel Pit, and he went back again hand again and down him to get the other place again. And he was
# The world seemed like such a peaceful place until the magic tree was discovered in London. The Duchess took the armour to talk. The Duchess took the sky in the middle of the forest. The Walrus said Tweedledee Alice began and shaking its mouth all round her unfortunate guests, and walked back to the game (whom she spied already had seen the side of the court as she could not hear them. "I’ve been very stiff again," Alice replied very readily, rather unwisely. "Then they had _not_ wash learn anything," said Alice, who was beginning to feel interested. "What can
# The world seemed like such a peaceful place until the magic tree was discovered in London. And I could spend its arm, and I can't swim, Owl, and you save all Pooh and Piglet were Generally, I am the opposite from a Bear to do afterwards." And these they went home to steal out, Replied, "Help yourself! Robin isn't a trap to be," and suddenly he put him into the lower part of the door, and then there was a pin to get out of the part of the Forest and Piglet went off together. Christopher Robin went
# The world seemed like such a peaceful place until the magic tree was discovered in London. They were short, though in the light of the pack of the song and truth fell along; he was too busy to spell the moment she went back as she went, and was afraid of that he was dancing this so still that she was now the moment to the part of the court put holding out in the middle of the court, for fear that were brook all over the whole forest. Chapter Iii. Advice from Araby, Lord High Chancellor): "Open the sun when the summers are....
# The world seemed like such a peaceful place until the magic tree was discovered in London. Oh, the time of the jury-stopping _is_ there. It would be very convenient fast in a minute or so he've been getting along a rope and went to call the Blue Spot, with the state, hanging on each side, and the more tightly in a tree wondering how awful he did, and then it was a poem on the stream, and he turned and got home and ever fell along Trespassers William, dinner, when he came to the part of the door-or he said happily, he soon out
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  3
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 586ms/step - loss: 1.2495
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. He was washing it in the morning, and doors are unlocked, and perhaps I've been thinking of the string, I haven't got a Contradiction." "I can't stay on the Rabbit Corner, and I should have to go down and find Piglet." Pooh looked at Pooh to nudge. "I'm not throwing it in the morning," said Pooh. "I expect it was a _very_ good morning," he said. "I shall have to wait for a Dangerous Place." "
# The world seemed like such a peaceful place until the magic tree was discovered in London. He was washing the sort of day, I should know _that_ I am in the morning, I can play whatever I thought of is when I say a Keeper from the Forest. I had a very fine sort of thing to do, I shouldn't know _what_ I'm doing," I said to Pooh, and Pooh was talking to himself, "What about a Postman?" "Thistles!" said Christopher Robin. "That's what you are," said Pooh. "I've
# The world seemed like such a peaceful place until the magic tree was discovered in London. And I was not the Zoo, we went round the edges of trees, and doors are unlocked." "I don’t know what you mean," said Alice. "And where are you going?" "I don’t know what to say," Alice objected. And a little a shriek of the King. "What matters it?" the King cried in a melancholy tone. "That wouldn’t be a very interesting dance, I know." "But the dog are worst of the window?" Alice said to herself, as
# The world seemed like such a peaceful place until the magic tree was discovered in London. The first question is not rain, Game to make a stuff in the Forest, and we wander down on the hill for the second head." "I see what I was," said Eeyore. "I'm standing with sticks about him." "I said," said Pooh at last, "I don't want to complain _if_ you have forgotten to go home with your umbrella for hours." And he felt that he didn't know where Tiggers said anything. He was quite the place with his pencil
# The world seemed like such a peaceful place until the magic tree was discovered in London. She would have been changed on the table, perhaps they see how sulky it was: and she couldn’t make out what to speak it had been with up and untwist a week before, thinking what there was like outside. However, she was walking away the oars of one of the blows fire-irons falling after the table in the middle of the court. As soon as she had recovered him when you drink in the garden before she could get in little knowledge of conversation, she trembled at this to be a person before she
# The world seemed like such a peaceful place until the magic tree was discovered in London. Here is a Daddy of Pooh and Trespassers William? And sometimes----" "Oh, Christopher Robin," he said. "What's warmer?" "There!" "About a sort of boat. I don't think so. While having Piglet were so busy as Christopher Robin's house. I thought it was. They are so too late for a Confused Noise Pot _here_. That was Mine _had_ a little something too, although I don't know. You didn't
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  4
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 590ms/step - loss: 1.2292
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. He was washing in the Forest And Kanga Has To Tim, And I go to Remove Stiffness for Tracking To Stiffness for Tracking The Snow Place By the Wolery Edward Bear, known the Forest Piglet spent his front door to show him to say: "I don't know I am talking about it." And he thought he would be too late for Pooh what he was. "I don't suppose it is _your_ birthday," said Pooh. "I
# The world seemed like such a peaceful place until the magic tree was discovered in London. He said to himself: "I think I am to be you." And he wrote up on the top of the Forest making his friends shared his song. "Hallo, Pooh," said Christopher Robin. "What are we going to?" said Pooh anxiously. "I thought it wasn't." "I don't know what it is," said Rabbit. "Nobody keeps the same thing to say how it is a Jagular at the beginning." "Do you see, Pooh?" "I don't
# The world seemed like such a peaceful place until the magic tree was discovered in London. They were washing in the dark wood, I think I am talking of the Forest, but I don't know what it is anybody else, and I don't know which it is either I can hear it." So he hurried on and longer that he could think, and he was very excited of this sort of board with another way which it was a crackling of unbouncing for it would be able to do; and I think he thought he was going to be Tigger and Piglet and Kanga
# The world seemed like such a peaceful place until the magic tree was discovered in London. She said to herself: "I don’t think I was saying to a King Bee for One Animals at once. Let me see—how _am_ it doing out? For I am a very Small Animal._ And I'm not a Bear That. I haven't got a lot of-- I mean I am in the river, I forgot. Sing Ho! for Small, I think I am a Puppy. And I think what I am. Ask him a riddle
# The world seemed like such a peaceful place until the magic tree was discovered in London. The Queen Of Hearts, and Tweedledee They were still asleep, and though they all decided the tree to go on by the floor. To a large sun called which she had peeped up to another thing to be executed, for fear of them bowed under among the white flower, with its wings for the blows size. Presently she took a minute or two who had got in "stupid," and the Dormouse turned angrily on a table out of the little brook, and sticking at the table. "What fun it
# The world seemed like such a peaceful place until the magic tree was discovered in London. The feeling I had gone at them now: This is a Very Little Brain to Bear, a bear, which it might mind-- And what _did_ become of him? A trifling and the more dead seconds, and I all hurried off my quietly instead of sand, and no direction was cold on the ground, and were able to make up the right size, and on each side of the words to the daisies, and then with a large plate she began to get them across the wood: the very
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  5
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 587ms/step - loss: 1.1991
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. If I could only go back and ask Christopher Robin I should like to go without the Zoo House, because I should lick and see Rabbit." Pooh sat down again, and pointed excitedly in a thistly corner of the hole. Then it was doing it at all, but he said to himself, "Oh, I see, if I was a Contradiction is looking for an Zoo." So he trotted off, put him his nose and began again. And then he thought that perhaps Pooh
# The world seemed like such a peaceful place until the magic tree was discovered in London. It's a Looking Tigger, and I don't know where I've been tole Pooh and Piglet and Tigger and Piglet were Generally, Piglet was sitting round his head and said "Oh!" and then closed his eyes, and Owl was nudging Pooh again, and said that he would all to him what he would do now when Pooh was doing it about the North Trees. But Pooh was at home again, and Piglet looked at him, and then patted to himself, "It
# The world seemed like such a peaceful place until the magic tree was discovered in London. ‘Come and get the sun,’ the Walrus said ‘Cut a minute to play!’ ‘Off with the dish!’ The Carpenter said nothing, and the crown, Whose shoes was whiter than it: The sands were Timothy the Important Thing For Tim. The King Whose Armour Didn'T Squeak Of Thomas Tom Of Appledore It was his buttons undone, and stood at the Big Spot Christopher Robin, who never were easier to mark there; And I want to sit
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was so pleased of settling help to be kicking again to say "Good-bye" and sometimes it was. North least it seemed to him it was very glad that it was a bunch of violets picked all a Sailor after Winnie-the-Pooh; F!C. E.C. Kanga never takes a happy morning to say, 'cos people know what I mean--if I mean--that that's why I've got a Contradiction, and you's Piglet." "Quarter past," said Piglet,
# The world seemed like such a peaceful place until the magic tree was discovered in London. ‘Are let’s nice one Now, for I? Who lives at me a lot for the passage to give them a match. But the other I should know, if I was to cut the same things not know whether you’d call saying I want to let them as they can." He was so ashamed of it at it, but the river couldn't be sure, that Tigger looked at it in case he had had got bigger lately, and the more he thought of this that Christopher Robin thought,
# The world seemed like such a peaceful place until the magic tree was discovered in London. As she had been waiting to write the way back on the floor. Then the Mock Turtle sighed deeply, and several perfectly were alive. The King had joined her her shoulder; "Why is the voice witness when his head is!" and shut her might three of the room in a voice (she drew her hair over her knee, and found a yelp crash were absurd. Alice heard in reply, "Ah, dear me!" more Alice severely, with a great little creatures.) "Fury said ‘_wabe,’
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  6
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 22s 588ms/step - loss: 1.1691
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. And when I were Emperors, And I were Four after Pigs. And I'm very fond of Mummy and see if I make Nuts and May Fall For Winnie-in-The Pond after Pooh and We Go for Small In It Corner for Water 1. Pooh runs downstairs To say "Yes and Flashed or Binker's Elephant who lives in the Zoo. I'm lying on my left ... I'm lying in the Palace since _I_
# The world seemed like such a peaceful place until the magic tree was discovered in London. He said ‘I've served and the day, I'm newting, I shouldn't know why, Pooh's always the Knights of Enormous Brain, and he wants to sit on the top of the door, and you can imagine Pooh's house, and I shall have a Good Thing If I'd better go for Piglets (or I can do forty-two; and they can't stop, but I've got a Very Small Animal." "If you don't know what I
# The world seemed like such a peaceful place until the magic tree was discovered in London. The Knave of Hearts were seated on The Queen, who Was standing as well as he could, Eager eye and willing ear, Lovingly shall nestle near. And The Panther was the silent at the Red Queen, trotting on a Dodo, "Well, what are it matter?" "I didn't bounce it," said Pooh, "and I can't climb downwards for him." "What did you say it was?" said Eeyore. "Yes, Eeyore," said Eeyore. "I'm
# The world seemed like such a peaceful place until the magic tree was discovered in London. The eldest the two raths outgrabe. "Beware the Usual Way," said the Queen. "I keep him when I was the only one thing in the bag," said Alice, who was beginning to see what Owl was doing. "It’s the stupidest tea-party I ever saw it." "That _is_ a narrow escape?" said Alice. "I haven’t pricked you smaller to say it," the White Queen said, without even waiting at all suggestion. "I’m dreaming," said Alice, "it’s
# The world seemed like such a peaceful place until the magic tree was discovered in London. There dear! I shall be a pocket-knife whatever to begin with bees, was a jar." So she took up his head out of her, and went with it in among the leaves, with "To your Majesty":, ‘I didn’t know, _why_, _I_ say, that’s a thin shabby-looking-cover argument! No, how puzzling the truth writes a white Knight will remain! But when the Pig is simply poohing The sea and fields, with sticky tales of a House: I sometimes _did
# The world seemed like such a peaceful place until the magic tree was discovered in London. And in his eye when he saw things on, she fell fast down. So she came to her feet at once. "Hallo, are," said Christopher Robin carelessly. "Ah!" said Eeyore. "Are we so very kindly lean with the end of the tree?" "No," said Pooh. "Which was the only one thing to be." "I ought to be and find them very birthday," said Pooh. "That's the point." "Do you think, Pooh?" "Expedition, they
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  7
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 588ms/step - loss: 1.1441
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. He was washing on the Zoo Farm-Saxon Squeak Christopher Robin and Piglet and Piglet were sitting on the Forest and Rabbit and Piglet were all playing in the Forest behind him, marched his mouth and said "Go on!" and then closed his eyes. "Hallo, Piglet!" he said. "I'm not throwing see Rabbit," he said, "Rabbit, I think. What are _you_ doing?" "I'm not asking," said Pooh. "I must go and see
# The world seemed like such a peaceful place until the magic tree was discovered in London. It may be a rich man, Sea! If you please I look on, I look down carelessly, I need, I need hardly on the river and escape, And I don't know I am a Clever Plan. Well, what's Christopher Robin? I'm lying on my left ... I'll serve and see I go whispering, and I don't know I am a Friendly Animal. I think I am a Camel who Is looking for a Camel who
# The world seemed like such a peaceful place until the magic tree was discovered in London. He would have a Clever Tale Of Enormous Brain whom I am Do. So I am about to read about _Another_ Knight and Piglet and Rabbit and Piglet and Piglet were all standing and said, "It's just Eeyore," and he began to wonder what Piglet was. "I've been thinking," he said. "I thought it was Piglet," and he went on, "I shall have to go back to the letter-box. And it isn't a sponge."
# The world seemed like such a peaceful place until the magic tree was discovered in London. A little wind suddenly was very well to be kicking on them, and when he was trying to look down and anxious that they stayed on his house, and then the other clean and more than the things wouldn't do anything, and Owl could try to climb on to it, and so he told Roo and Piglet to think, and Roo, who lived near Roo, who to be Christopher Robin. And Pooh saw Piglet that Piglet and Piglet were both over Christopher Robin's house and Piglet
# The world seemed like such a peaceful place until the magic tree was discovered in London. It is, a sort of tree, And the sun comes slanting by a gate or brown And such new things who knew it and there, If the Emperor Got in the Blue Tattoo. Came along, as if I am Three or Organizing Kangas." So he got up early, with his eyes and listened. It was getting so fast one or fifteen: then he had learnt the balloon at the other verse of the Forest. And Smallest Bear learnt his Twice, and Christopher Robin
# The world seemed like such a peaceful place until the magic tree was discovered in London. So they were beginning in twice of fur and kindly smile that a moment’s meal of it had come on in the afternoon, and, when Pooh'Did I, an Expotition with Flying for him, or that was all the honey as he loved Eeyore; and just as if everything was Not and A Notice Signed Surrounded during Which they should know once silly when his mouth was tied, and then he was just going to throw the East Pole. But every Extract of Malt was gone after
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  8
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 588ms/step - loss: 1.1157
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. "I suppose you don’t mean three of the Zoo, you know, Piglet, and I should think it was honey to me." "I can't get down," said Piglet. "I don't want to have a mistake of a poem and I built myself." "You don't know what you mean," said Pooh. "I thought it wasn't." "Why don't they?" said Pooh anxiously. "Yes, you're going to discover a Pole," said Owl. "I don'
# The world seemed like such a peaceful place until the magic tree was discovered in London. The eldest Oyster winked his eye, Alone the Lord High Coachman laughed at the Forest, trotting on and his mouth and looked at the Hundred Acre Wood and began to polish up it. "It's a very funny thing," he said to Pooh, and in his eyes and then suddenly at last. "It was the wind on the Forest," said Pooh. "I was forgetting it up to me than Eeyore." "I don't know you," said Pooh, fidgeting a little .
# The world seemed like such a peaceful place until the magic tree was discovered in London. She would have a Mysterious Animal who seemed to speak half the chimney-tree, and when he wanted to do that he was making straight to the Hundred Acre Wood so now. "What it was a perfectly good one?" asked Rabbit. "What do _you_ say, Piglet?" "No," said Pooh humbly. "It's bad enough," said Pooh, fidgeting that. "I'm leaving it and _him_. You're clever one of a bush, or perhaps I'll go round him
# The world seemed like such a peaceful place until the magic tree was discovered in London. "What trial does it doing?" cried Piglet. "Yes, and it's just here," said Tigger. "That's a good Animal. But I hope I saw a Tigger. It _is_ it in the morning. And if you were an Good Thing to read about backwards. The Knight and Piglet and Piglet came strolling along, and the noise was stick Pooh or Pooh, and Tigger said he thought you would be a Grand Idea to be done about him. And
# The world seemed like such a peaceful place until the magic tree was discovered in London. Oh, tell me how God began!" "But you should be five times as well by considering," Alice objected. "And I don’t understand all this question, at any rate, certainly, at all," said the Hatter. "Then there’s nothing of my child, and you can’t have no idea, you know—and days like to begin before." "She looked a little yards than she heard the Red Queen. "Besides, I beat it purring here first, that I’m doubtful about a little weight and a piece
# The world seemed like such a peaceful place until the magic tree was discovered in London. Yet they know if well was the sort of a well or two, giving the fluff he had come back, so that it was raining already, so that none of the guests began away to Roo, who Wol had written his little rock on the stairs than him. "Bother!" said Eeyore. "Are he going home?" "Tigger, you're not complaining with things having a Cunning Pole," said Piglet. And he murmured to himself three times at last. * * * * * When they asked
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  9
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 587ms/step - loss: 1.0843
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was not a moment to be lost the White Queen’s hands coming out of the house where the trees had been broken to pieces, and seemed to listen to the tree till she was out of sight of the other side of the counter. Alice ran on a little pattering of footsteps till she found herself actually run on their slates, and she was now about this time till she had recovered the Red Queen. She was just beginning to think that it was a regular rule, and she found herself with the
# The world seemed like such a peaceful place until the magic tree was discovered in London. She said the door and the King Of his song: It was the borogoves, And the mome raths outgrabe. "Beware the Jabberwock, my son! The jaws that bite, Take the pudding. Off with his head!" "Chorus again!" cried the Gryphon, and she went on with great interest as she spoke, and ate it a little Lily, and neither came up the White King, and tried to hide a good little leaves for herself, and was sawing over it again. "I don’t think
# The world seemed like such a peaceful place until the magic tree was discovered in London. She ran and walked from the grave place at the door, staring stupidly up into the valleys where she was two or so savage, and as if it had been afraid to the Eighth Square to be oysters: the shadow of hers was standing and more human with the fire in a great wall—such then she was good practice, when she had its head into her sister she caught out on a little pattering of footsteps in the distance, and she fancied that she was eyes to open a bit hurt it, and crept a
# The world seemed like such a peaceful place until the magic tree was discovered in London. The first question Did gyre in the golden nose she came flying out of Kanga's house and Kanga said, "No brain with the river for a little smackerel of something that is a Confused Noise." "Oh, Eeyore!" said Pooh, looking at it again, "I don't know it was a perfectly day." So he poured a stick in his tree, and the more tightly he said, "Hallo, Piglet, my Majesty," and Roo bent down at the notice, and said: "
# The world seemed like such a peaceful place until the magic tree was discovered in London. It would be for a very Turtle—we used to call him Tortoise— If you make I die to Humpty Dumpty or I can'do it in the afternoon. You haven't really Hot with The Little Brain, but it is in the afternoon." Pooh had had a tiring good at riddles and as if it was happening. It is a very long morning Pooh had been bouncing at the tip of Christopher Robin, who had just come to the Problem of Escape and Piglet. "Are
# The world seemed like such a peaceful place until the magic tree was discovered in London. She did not mind why how to begin it ever to do, no one. When the Emperor Got You were Four Presents And We's first Sixpence? Special Bear and Early (or any of them), A Grand Bear! I saw him what who did he knows. He rescued his Twice Times. He had to write this on the top of the Forest lately, but it's Grandfather Goes by the Important Flood. Who a little Song. The Little
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  10
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 587ms/step - loss: 1.0636
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. And when I had to go on the sky for the second one of the year, and then I should know what I mean I did blinch a little something to do with the Outdoor Bit Thing in the Forest. Sing I like to play the way of a Rescue Pot." So he went on singing it was climbing trees and Piglet to see what had happened. And then he said: "Who is a Grand House among us about my little corner of the hill." "
# The world seemed like such a peaceful place until the magic tree was discovered in London. The eldest Oyster winked at him. And the look in the little grey town, And all them the same size, the tale was shining on the head, and wool, and more human, and more sounds of broken glass. "I don’t know what you mean by ‘glory!" she said. "I wish you don’t mean the Red Queen, and the Queen said—" "What a pity!" said the Gryphon. "I don’t know what’s such a riddle as you go." "And that I’ve got a little
# The world seemed like such a peaceful place until the magic tree was discovered in London. I had to have washed it for us, letting things come to the top of it you can see, and if it is a Mock Turtle only looked at him: and the Queen came out from the trumpet, and the King was sitting on the trumpet, and the Queen merely remarking, "I won’t be go on here!" But she got up once more than the Mouse, who was always tripping over like life. Chapter Iii. The Lion beat The Unicorn Alice all made up quarrelling up
# The world seemed like such a peaceful place until the magic tree was discovered in London. When there are very well of getting the other, and blew up the time. I know I am no one, I shall have a joke on my nice new nose, I couldn't have to climb up and watch on the Trap by a Pleasing Manner, such one Knight. Can't you see what I mean?" And then he wrote away very quietly at Pooh's house, and Tigger would know what he had sang it again. "One brain of _washing_," said Eeyore. "
# The world seemed like such a peaceful place until the magic tree was discovered in London. When I had a wonderful plan to The Great Pump. But it says, "In the world notice I could jump." Rabbit would have gone a Very Little Brain whom Tigger could escape by Climbing for Pooh. And every right Tigger happened to meet Christopher Robin's house and Piglet, Piglet was sitting on his branch while he said: "Who's the good of a lesson, but I did was looking for a balloon?" "Yes," said Kanga, "is the time
# The world seemed like such a peaceful place until the magic tree was discovered in London. And what I get up the rest of the hill!" And off it seemed to tell him when the Queen came through, without getting entangled to the ground. However, this time she found it off a regular Lily, but she soon started to the Gryphon, for it flashed across the other side of the counter. "Nearly like fair!" cried the Queen, tossing her head contemptuously. "You’d be nowhere to obey!" cried cried Tweedledum. "I can’t do it," said the Unicorn, "in fact,
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  11
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 587ms/step - loss: 1.0283
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. And when I were Emperors, If I were Kings, If I'm Dragons, and I call her Nan and Factors, I mean to myself ... I'm lying on my left and see Owl's house and I'd go away to John and Piglet and Piglet and Piglet and Piglet and Rabbit and all and Piglet and Piglet and Piglet came strolling along together. He said "Hallo, Eeyore" and Kanga said nothing, and now a tear or two he
# The world seemed like such a peaceful place until the magic tree was discovered in London. I think I’ll go down the spinney as if you tried it if I could only look down and make a Very Small Thing to read you." And then he thought to anybody proudly, Kanga passing the Heffalump talking to the side of the Trap in the Forest. "Come on!" called Pooh, and Pooh and Piglet together. And he came off to the Six Pine Trees, and tried to say something helpful for a little. "I shall call it here." "Thank you
# The world seemed like such a peaceful place until the magic tree was discovered in London. The Pool Sends in the Blue Spot It was written to him. So the door in his eye, The Little Black Hen Alone was, It said, And through the sheep, An india-rubber ball, Some say he couldn't. Good King Hilary Looked at his Chancellor (Proud Lord Willoughby, Lord High Chancellor): "Open the window Quickly, quickly, Walk to the wicket-gate And see who is knocking. I think I am a Camel who is
# The world seemed like such a peaceful place until the magic tree was discovered in London. And as I get upon an Zoo To stiffen him. You put him a Cloud himself and Piglet can tell for paw, and if it might be able to be useful. You're going on an Expotition And I are living in the Forest. No, I can't read to see what I mean--that I ought to go away in the morning." Pooh said very quickly, "I shall have to swim for a Backson Months." And he thought as he started to
# The world seemed like such a peaceful place until the magic tree was discovered in London. He always, last "The End and Queen, and the King Of Hearts. They made him to leave off the chimney-and-butter, and they repeated and she stood there so quickly that it was only over this a few yards off in her pocket, that she turned round and make a large pool (which was a word, but her face brightened so to itself to make out what it was in disgrace. However, she soon grinned so much of it that was going to shrink the last disgust; and it
# The world seemed like such a peaceful place until the magic tree was discovered in London. "Do you know the Brain and I are said thinking," said Pooh. "Everything _is_ there. It has an--and not better tell mine, if you promise we're _suspicious_! What about you going to?" Rabbit jumped into a hollow behind a tree with his head outside, and said in a loud whisper, and he looked up at her again. "What is his sorrow?" asked Pooh. "I don't." "Why what I like," said Pooh. Eeyore slowly beautifully was
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  12
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 588ms/step - loss: 1.0072
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was washing them in the sky, and dance are Christopher Robin anywhere about? You'm just the same for a Bear. I can't sneeze and see Christopher Robin. He's got in the wind. And then he brightened up and knocked and knocked until he got to the top shelf, and then he feels Wednesday, and I hope I am a Bear, and he's a Very Small Animal not to blinch that we can tell with paw." So he thought that he would
# The world seemed like such a peaceful place until the magic tree was discovered in London. He was on a warm spring, I don't know if I know where I mean, It is easier to do with Roo about to you. And I'm sure to have mastershalums all the honey in the Forest. Good-bye. Candles and a little dead Useful." So off he went back to the Goat, and Pooh said "What happens?" "Me," said Kanga. "What you have been the mischief for you," said Christopher Robin. Chapter Vii In Which
# The world seemed like such a peaceful place until the magic tree was discovered in London. It's always a hummy sort of day outside." "Oh, well, I didn't know what I didn't like it," said Pooh happily. "Not, yes, it's just one of us." And he wrote round the Forest's door and all seemed to be known, and Pooh was saying, "I'm just telling everybody a little bit of Poetry, and I _know_ it was a very good idea, I shall go home and see Christopher Robin's house. A Very
# The world seemed like such a peaceful place until the magic tree was discovered in London. He said it was his teeth. John is rushing down the pane, I think that, if I cry to a nicer day, I play up-- All around the table, And nobody knows it teases, and four one Knight who knows him well, He sits on him now. He had a sort of look called Me, I shouldn't much care to see The way out of the Shark, I shouldn't much mind If it's gone. Don't talk away and see Christopher
# The world seemed like such a peaceful place until the magic tree was discovered in London. And it doesn't seem to matter to see much.' So when I'm Emperors!" And then, just as he woke through a paw and escaped in one of them in the water, and bumped down gaily, breathing over the tracks, and pulled up and down. "I see, Pooh," he said. "I am _not_ better if you are with this I knew." And then he put his front leg in his mouth and said "Oo, Tigger!" and---straight up round his
# The world seemed like such a peaceful place until the magic tree was discovered in London. And every one says that moment Good-bye, which is quite different on outside. So she came Rabbit who couldn't know where Pooh was; and if I'm all to Winnie-The Pole of the Fiercer Animals. Wind of a Bear! Sing Ho!" Eeyore (_modestly disappointed_): "Ho-_ho_!" . Piglet didn't much Pooh, and he put his paw down his hoof again from another smile. "Help, dear!" said Kanga, very much impressed by the daisies,
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  13
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 593ms/step - loss: 0.9871
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. He always found a sort of boat, and he wanted to float or a lark and a railway station." So he thought that he would never be able to talk for that he didn't like bouncing, and he knew that it was a Sailor after a Clever Place. And Piglet, who had a spoonful or two of the floor he was really, and when he was getting so sure that he would be able to count, So he did it about Tuesday that he hadn't had a Very
# The world seemed like such a peaceful place until the magic tree was discovered in London. You looked at the back of the river, and doors feels to be a Cloud which knows what you were saying, but I shall have a Clever Animal is too busy to say 'How was he fifteen? He just that of all the Knights Are It One of Its Little Brain first." "Oh!" said Pooh. "There's Pooh!" Pooh scratched his head, and swished his tail at it. "That's right," he said. "I suppose you're _not_
# The world seemed like such a peaceful place until the magic tree was discovered in London. It was the only one in the afternoon, which I should put him into the wind. Oh, I had a shame, I will have got it on the Trap, I shall have a joke on my little cherry, I need hardly it was to go and make up the rest of the year." "I thought it was asking it," said Pooh. "I thought it was a Jagular, but perhaps poor Eeyore's house is a good thing to bounce, and I shall come up and
# The world seemed like such a peaceful place until the magic tree was discovered in London. Ah, I know it, it's a nice jar!" Piglet had got up the tree, and then found his friends and his house, and Pooh was telling Pooh to breakfast. Piglet was just beginning to tell it that he was winning of the Gravel Pit, and if he had been a Very Important Animal heard all a Loud Heffalump where it meant--that we were trying to do, and Pooh could escape by Jumping, and Tigger whispered nothing, but as he loved Piglet, because however
# The world seemed like such a peaceful place until the magic tree was discovered in London. Here I could tell that much of them, I couldn't see mine," he said to himself, "that would be just the wrong one of string Pit, we would let me have houses." And he moved off; and then he walked home in this place and then he found Roo with him, and feeling very happy when he had only a few haycorns, and Roo fell on to Pooh, and waited hopefully ... and he knew a Very Clever pup-pup-pup Clever pup-pup Plan.
# The world seemed like such a peaceful place until the magic tree was discovered in London. It's no Space, And I'll have a house where the wind might count, So I can climb down the other rest; And he Was Rabbit and Alexander Beetle Was taller. The wind was along in the middle, And the trumpet's blast, They have Anne, I don't care Because the wind goes, Not ready to brush on by and such a lot of Mummy and see, but this doesn't what I mean. Chapter X In Which _A
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  14
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 22s 598ms/step - loss: 0.9543
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. He's thumb, and I'm waiting for a Heffalump of Me. There are days when I thought of a Rocket Man who's always a little something which can spell Tuesday. What's Piglet? I'm just thinking, and I'm waiting for a Heffalump which I can't miss." And then he thought that perhaps perhaps Christopher Robin and Piglet and Piglet (or I were a Mistake, and Tigger and Rabbit and Rabbit were all standing against Pooh; and
# The world seemed like such a peaceful place until the magic tree was discovered in London. Let me see, Piglet?" And he went on singing. But it was a very long story to be a Sailor after the Forest, and he wanted to say that, if they had decided to be told him when he thought the whole world had blown into and handed it carefully across his toes, where it didn't know how awful it was going to say, "Discovered by Pooh, Piglet?" Pooh plunged into the water, seized the deep whisper, and said, "I wonder what I mean,
# The world seemed like such a peaceful place until the magic tree was discovered in London. I'm just wondering, I'm falling down and go for me." Pooh was saying, "Oh, dear!" (_Politely_): "I'm sorry I thought I'd better go back!" "Well, I didn't know," said Pooh. "Haven't Brain," said Pooh. "It's a very particular," said Pooh anxiously. "Splendid, I sort of honey," said Eeyore. And he jumped off importantly. But Pooh was telling them what he would do, they could
# The world seemed like such a peaceful place until the magic tree was discovered in London. I've been thinking it was quite different on the top of the jar. I think I should be a Contradiction is looking for a little something, because I'll tell Owl or Owl, and I think I am a Trained Brain which seemed to go here, but I should have to give a party, but the Educated, a Bear!" Chapter Iii In Which Piglet And I go up By A Tight Place, and Kanga Has A Bath Nobody seemed
# The world seemed like such a peaceful place until the magic tree was discovered in London. Let’s just Stigand, the woods are up them to do! For instance, a minute, there’s no harm, I and won, come away, Kitty! Do cats eat bats? Will you tell you?" And she began nibbling about in a moment of the six cat, and fire-irons gently "Off Marmalade!" but (after she was out of the trees, hardly touching the ground with the fire, and skurried down his head into a pot: one of the miserable the Mock Turtle had flown in search as
# The world seemed like such a peaceful place until the magic tree was discovered in London. (_I keep him, it's funny!_ 4. For," said Pooh and Eeyore! Chapter Viii In Which Pooh Does Entirely Surrounded By Water, and Tigger Has A Bath Nobody, and The Poem and Beetle Of Very Little Brain, And the Forest who said at first he she ought to know whether it was going ... and it was that anybody were fifteen. So by a time Christopher Robin said nothing, you said, Piglet settled at it.
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  15
# File 'chaos1.txt' found locally. Using it.
# ...
# epoch:  18
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 586ms/step - loss: 0.8448
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. I wonder if I could only get it up and ask us." "I never thought they liked everything again," said Piglet. "I wonder what you were saying, and then I can't think it was a Jagular." "You don't want to be a Useful," said Pooh, sniffing slightly, "that there isn't any brain left about just in my day, and then I should walk away and start licking myself. Do you think you're going to do it?" "Oh, I
# The world seemed like such a peaceful place until the magic tree was discovered in London. The eldest Oyster winked at her: When something sudden came in the air, And frowned to see below The happy and Sir Thomas found his noble health, And a crown which couldn't because of the state which He's always new Knights, and he sometimes likes To Do. "I'll tell you where I did," said Rabbit. "I've been thinking," said Pooh, "but I didn't know what you are interested." "That's right," said Pooh. "Oh
# The world seemed like such a peaceful place until the magic tree was discovered in London. She had once seen this a few yards of Alice’s Knight, who wanted to be a Pooh, which is why he had a sort of day which Christopher Robin looked at each other, and shouting "All this washing the Forest and Me and Piglet and Piglet and Piglet and Roo bent down to Piglet, and Piglet and Piglet jumped up, and Piglet said, "This is A New House." So he went to the Six Pine Trees behind his house, and Rabbit
# The world seemed like such a peaceful place until the magic tree was discovered in London. She said she didn't mean it, and when we've got to the top of the story, or it's a good time, even he felt that it feels he had seen Piglet on his back in a south part, she and Winnie-the-Pooh, who felt making it in a very friendly of Tigger, and sometimes he wonders what Christopher Robin would be saying "How do you do?" Christopher Robin said, "You were a treacle of _them_ to do it." "That's the whole
# The world seemed like such a peaceful place until the magic tree was discovered in London. And when I found the door was shut, I was very proud and I tried to hum If it snowed and he'd begun With a coat of the largest; When his eyes came up, Though very much from his Right On Araby, The Little Black Hen Is Not Two-- But Bad Bear coughed in a Hundred Acre Wood By the Wolery, and Pooh, F, and Pooh, the butterflies said Good, and Christopher Robin and Pooh and
# The world seemed like such a peaceful place until the magic tree was discovered in London. The eldest Oyster winked at her. She was in a jar of feet on the way, and the soup went back to the game. "I wish _that_ doesn’t have got it," she thought, as she turned the baby tried, and crawled at the Lizard in silence. Alice knew she might as well wait and see the next tumble of the trees of the March Hare with the Gryphon, for a sudden to speak by the chimney, and then raised himself to where the White Queen, who was
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  19
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 602ms/step - loss: 0.8141
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. She said she was sorry, but the Forest was still going on within—a constant howling in a puzzled of the room, which at last in such crowds the sneeze of the Mock Turtle’s heavy sobs, (for the White Rabbit came into a moment, and tried to beat the Lizard to be that they began to do it: she could not remember ever having heard so, but she felt that it was no one to be lost, as she was shrinking rapidly, she felt that it would be the Cat again, so
# The world seemed like such a peaceful place until the magic tree was discovered in London. She _never_ could see him to introduce a moment, she was lying on a tree as if it was the right fellow, you may seem shake it among the Rocking-horse-fly with the heather, some of the song, and the cook had vanished in the chimney, being dream, with the reins hanging loose in the lap of the tree, with his head in the lap of the Queen, who seemed to be full of soup. It seemed to be that it was a civil question to be done in the Looking
# The world seemed like such a peaceful place until the magic tree was discovered in London. All the Queen of Hearts were seated on a little glass box, which seemed to be full of soup. Chapter Iii. Looking-Glass Insects Of course the first thing to do is to find a grand survey of the country the Queen and the Unicorn were seated on their fur deep Anglo-Saxon attitudes, and the Queen went by the Queen, and several large sight of the Mock Turtle, who looked at the Queen till she leant forwards were large elbow, and it ended in her hand
# The world seemed like such a peaceful place until the magic tree was discovered in London. The little dry I were whiter than The Panther and made of them." "And a joke you’ve flown down," she said, "that one can’t like changing a worm. And then you’ll be a Queen—But you’ll take no use their putting it away him! But I wish if I could see you to do it!" "Do you know what to do next?" Alice asked, feeling a little thoughtful little needles. "They’re thinking of them—at your temper and round, that I don’t see what a
# The world seemed like such a peaceful place until the magic tree was discovered in London. Was the Queen, And the first I had been written by the English, who wanted to know The White Queen Alice was under the little pockets of the tree, and the Red Rabbit looked at each other. "It wasn’t very pretty," she said, "it’s foolish to cry about. I only wish I could get back there, for I have finished it!" "Off with the first verse," said the Queen. "It isn’t fair!" the White Queen moaned, wringing her the
# The world seemed like such a peaceful place until the magic tree was discovered in London. Like Owl in the Forest, Alone among him. Good King Hilary Looked at the beggarman, He said "Yes, dear, stick!" and never notice of something to go in at once, but it was the sort of thing to ask who I mean--that _that_ would be being lost here all alone, you would all know what they were never get un-birthday in-the-box all a piece of string, there was a Very Bouncy Animal, much and misty came on purpose about, when there
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  20
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 584ms/step - loss: 0.7914
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was washing them out again, and she knew that he would never see it in a sort of dream, though it was the only day of the Forest, gorse and bracken and heather, and bounced--and the other clean of honey, and Felt at the door was in the middle. In the very middle of the tree there was a level strip of grass, which was gone in sight of the next peg and jumped up again. "I suppose it encouraged to squeeze at home," she thought: "and if
# The world seemed like such a peaceful place until the magic tree was discovered in London. And when he had finished, he could spell the honey to go, and the story he had been with the acorns for it. And he was wondering honey to go along, and it was a sort of good-malt sandwiches for some of the words. "It _is_ the clock, and he might notice," said Pooh sorrowfully. "It's a comforting of poetry," said Pooh. "Oh, I see," said Pooh. "Can they fly too?" "Yes, Eeyore, I will be _him_
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was washing them out again, and this was certainly it was a _little_ ashamed of fighting for the Duchess, or Longitude they could. No, I ought to be getting _him_: I wish you were playing else, and I ought to know—" (for she couldn’t see her feet high in all directions, and said "Thank you very much to have a real treat. Well, what I might get it up," he said, as she set to work and fanned her again. "It’s a moral
# The world seemed like such a peaceful place until the magic tree was discovered in London. She looked down at full times, so that it was all very well that way to be a bunch of violets, and when he had had a few flowers down to the place where Eeyore was doing. And they played the Heffalump in front of them and threw them to walk about the words; and Owl had got so an Forest who had a sort of look as if you were Eeyore, and Piglet said that if he had been all in it from the day of the Forest, and Tigger and
# The world seemed like such a peaceful place until the magic tree was discovered in London. She got a little bright yards in the middle of the Forest. So, where was Unsettle Things? (_For where?_) And "_Round_ about And _round_ about And _round_ about I go; I think I'm not too. I haven't got a bell-box, but I don't know why. Ask me a riddle and I reply: "_Cottleston, Cottleston, Cottleston Pie._" Pooh still said "Yes," and felt proud. "Come. Same."
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was still patiently undergoing its toilet, "and this _is_ it like it?" "Yes," said Piglet. "My favourite size." "Well, if they can talk what to-morrow is," I said. And I want--if I call a Backson who Is looking for _another_ are Man?' I find no present for Pooh and Me when Pooh Corner with Tracking'' surrounded for Eeyore ... and we've got to sit at it. And we've come to stay
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  21
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 586ms/step - loss: 0.7628
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. He was making thy hat as he got there, I could spend a happy morning Seeing Roo, who is coming to be there To lay in the Palace since I was four after the wind for escape. I'm very fond of Daddy and I don't know where. He's a very big Tigger who is looking for a walk. So I think I am a Camel who Is looking for a Camel who Is looking for a Camel who Is looking for a temper,
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was washing them a little more to say to her to the fire, and then they were taken up with bunches of stick in the sea, and now it was the way out in the forest, and expecting it back to the English to be a few yards of Alice, and she was getting quite out again, and held she very hard on her ears and sprang off into its face and very glad to see that she could stop the point. "I don’t know what you’re thinking about," said Alice.
# The world seemed like such a peaceful place until the magic tree was discovered in London. But I could get up this morning. He becomes Educated, a Small Tigger, a Melancholy Tigger, a Melancholy Tigger, a Small Tigger, a Small Tigger, a Small Tigger, a Thing was as it could do to keep up with the same sort of beetle, and there are not quite sure whether it was a very big animal or not to see if he was making a nice taste or two, giving Up for them, and then he picked it up again and put it back,
# The world seemed like such a peaceful place until the magic tree was discovered in London. So I could spend a sort of beetle For I'm waiting, and I call her Nan ... But he's a Nanny who is always I'm doing, I shouldn't much care If it was going to know ... I'm lying on my left ... I'm lying in the dark I can't bird, but I'm lying on my left ... I'm lying on my left ... I'm lying on my left," sang Piglet happily.
# The world seemed like such a peaceful place until the magic tree was discovered in London. I'd given him this is a very good fir-cone, and I can't read it. Chapter X In Which Eeyore Is Entirely Surrounded to Rabbit_ lived and showed me a little cloud Right. Chapter Viii In Which Piglet Has wheezles And sneezles And sneezles, They bundled him Into His bed, Or a line and his Are something playing But nothing Is and a useful pond. Good morning I had his little ways. He had a very strong of soap
# The world seemed like such a peaceful place until the magic tree was discovered in London. Yet! Oh! Daddy is clever!" (For a long silence, he began to eat that of anything was, had a knock down between it, and was leaning in the place of the room to listen in his chair. * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * "Tickets, please!" said the Caterpillar. "I’ve
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  22
# File 'chaos1.txt' found locally. Using it.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 21s 592ms/step - loss: 0.7401
# finished training...
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was so much as if she had known them all the time he had been dancing and looked at himself, and he was back to the part of the Forest, and Wanting to Count Things--like Anything. 2. But Kanga wouldn't discover the difference, because Christopher Robin and Rabbit and Piglet and Piglet and Tigger were all playing Poohsticks, he said, "Discovered by Pooh anywhere about, Pooh dear, but I'm waiting for that tree and Eeyore and Piglet," and
# The world seemed like such a peaceful place until the magic tree was discovered in London. And she was so frightened to say "Good-bye" and "Thank-you" to Christopher Robin, and Pooh looked at him admiringly, and Pooh explained to everybody, and he knocked his head and drew the warm of the Forest where he had thought it was. "There!" said Owl. "I thought it was a special sort of thing," said Pooh. "It was." "I don't know you were playing," said Christopher Robin carelessly. "It's a very particular morning thing, and
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was so much to carry of them that she had never seen soldiers so uncertain on their heads to say "Drink me," he said, "that is it Oh?" "So he did," said Pooh. "What are we going to do?" "It was an A," said Piglet. "Which was a Jagular," he went on, "because Eeyore, who is a friend of mine." "Oh!" said Pooh again. "I didn't really want to come swimming, looking for me
# The world seemed like such a peaceful place until the magic tree was discovered in London. She was so much to climb up the tree to see if the two man said "Good-bye," and then hurried on to Pooh as he could. "I expect so was me," he said. "Yes," said Piglet. "I dropped it too," said Piglet earnestly. "It's a very particular morning thing." "Oh, well, it goes on ‘_the A Bad Accident_." "But I think it was." "Oh, well, if you want you a perfectly good one,
# The world seemed like such a peaceful place until the magic tree was discovered in London. Till he looked up and down as high as anything, and Piglet's ears came out and said "Go away?" "No," said Rabbit carelessly. "I don't think you were all right," said Pooh. "As long as we can look in it on it, and then you'll be late for. I have a house of some kind, made to Piglet." "So it is," said Owl. "I don't want to come and find Christopher Robin." "He was the
# The world seemed like such a peaceful place until the magic tree was discovered in London. This is a sort of Bear, a Horrible Little Black Inches," cried Bear, "but there's Piglet." "You're so sorry," said Eeyore. "It's Small!" cried Piglet. "And I said he was smaller -The Floating Bear," said Eeyore gloomily. "That's the house for Owl. He talks about sensible things, but then we'll do it again." "But, Eeyore, I'm afraid you are," said Pooh. "Well, give me
# samples produced...
# garbage collected...
# session cleared (to save memory)...
# epoch:  23
# File 'chaos1.txt' found locally. Using it.
# 31/34 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - loss: 0.7115
